# %%
import pandas as pd

orders_columns = ['order_id', 'order_date', 'order_customer_id', 'order_status']
orders_df = pd.read_csv('D:/DE projects/project/data/retail_db/orders/part-00000',
                        header=None, names=orders_columns)
orders_df
# Out:
#        order_id             order_date  order_customer_id     order_status
# 0             1  2013-07-25 00:00:00.0              11599           CLOSED
# 1             2  2013-07-25 00:00:00.0                256  PENDING_PAYMENT
# 2             3  2013-07-25 00:00:00.0              12111         COMPLETE
# 3             4  2013-07-25 00:00:00.0               8827           CLOSED
# 4             5  2013-07-25 00:00:00.0              11318         COMPLETE
# ...         ...                    ...                ...              ...
# 68878     68879  2014-07-09 00:00:00.0                778         COMPLETE
# 68879     68880  2014-07-13 00:00:00.0               1117         COMPLETE
# 68880     68881  2014-07-19 00:00:00.0               2518  PENDING_PAYMENT
# 68881     68882  2014-07-22 00:00:00.0              10000          ON_HOLD
# 68882     68883  2014-07-23 00:00:00.0               5533         COMPLETE
#
# [68883 rows x 4 columns]

# %%
print(orders_df['order_status'].unique())
orders_df.query('order_status == ("COMPLETE", "CLOSED") and order_date == "2014-01-01 00:00:00.0" and order_customer_id >= 10000')
# Out:
# ['CLOSED' 'PENDING_PAYMENT' 'COMPLETE' 'PROCESSING' 'PAYMENT_REVIEW'
#  'PENDING' 'ON_HOLD' 'CANCELED' 'SUSPECTED_FRAUD']
#        order_id             order_date  order_customer_id order_status
# 25888     25889  2014-01-01 00:00:00.0              10045     COMPLETE
# 25919     25920  2014-01-01 00:00:00.0              12232     COMPLETE
# 25920     25921  2014-01-01 00:00:00.0              12373     COMPLETE
# 25925     25926  2014-01-01 00:00:00.0              10468     COMPLETE
# 25926     25927  2014-01-01 00:00:00.0              10278     COMPLETE
# 25957     25958  2014-01-01 00:00:00.0              11124     COMPLETE
# 25962     25963  2014-01-01 00:00:00.0              11546       CLOSED
# 25964     25965  2014-01-01 00:00:00.0              11642       CLOSED
# 25974     25975  2014-01-01 00:00:00.0              11405       CLOSED
# 25977     25978  2014-01-01 00:00:00.0              11726     COMPLETE
# 61897     61898  2014-01-01 00:00:00.0              10152     COMPLETE
# ...

# %%
orders_df.groupby('order_status')['order_id'].agg(order_count='count')

orders_df['order_month'] = orders_df.apply(lambda order: order.order_date[:7], axis=1)
orders_df.groupby(['order_month', 'order_status'])['order_id'].\
          agg(order_count='count')
orders_df.groupby(['order_month', 'order_status'])['order_id'].\
          agg(order_count='count').reset_index()
# Out:
#     order_month     order_status  order_count
# 0       2013-07         CANCELED           22
# 1       2013-07           CLOSED          161
# 2       2013-07         COMPLETE          515
# 3       2013-07          ON_HOLD           81
# 4       2013-07   PAYMENT_REVIEW           19
# ..          ...              ...          ...
# 112     2014-07   PAYMENT_REVIEW           54
# 113     2014-07          PENDING          517
# 114     2014-07  PENDING_PAYMENT          979
# 115     2014-07       PROCESSING          561
# 116     2014-07  SUSPECTED_FRAUD          101
#
# [117 rows x 3 columns]

# %%
# Join between Pandas dataframes.
# DO NOT RUN THIS CELL.
customers = customers.set_index('customer_id')
orders = orders.set_index('order_customer_id')
customer_orders = customers.join(orders, how='inner')

# Writing dataframe to file.
orders_df.to_csv
orders_df.to_json

# %%
orders_df.sort_values(['order_customer_id', 'order_date'], ascending=[True, False])
# Out:
#        order_id             order_date  order_customer_id     order_status  \
# 22944     22945  2013-12-13 00:00:00.0                  1         COMPLETE
# 33864     33865  2014-02-18 00:00:00.0                  2         COMPLETE
# 67862     67863  2013-11-30 00:00:00.0                  2         COMPLETE
# 15191     15192  2013-10-29 00:00:00.0                  2  PENDING_PAYMENT
# 57962     57963  2013-08-02 00:00:00.0                  2          ON_HOLD
# ...         ...                    ...                ...              ...
# 5302       5303  2013-08-26 00:00:00.0              12434          PENDING
# 4798       4799  2013-08-23 00:00:00.0              12434  PENDING_PAYMENT
# 1867       1868  2013-08-03 00:00:00.0              12434           CLOSED
# 41642     41643  2014-04-08 00:00:00.0              12435          PENDING
# 61628     61629  2013-12-21 00:00:00.0              12435         CANCELED
#
#       order_month
# 22944     2013-12
# 33864     2014-02
# ...

# %% [markdown]
# **THE END!** (5 cells total)
